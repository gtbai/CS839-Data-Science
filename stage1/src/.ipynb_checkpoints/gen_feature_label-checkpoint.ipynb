# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# @Date    : 2019-03-04 17:31:29
# @Author  : Bruce Bai (guangtong.bai@wisc.edu)

import os
import pandas as pd
import numpy as np
import re
import timeit
import random
import nltk

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)

# %%
FILTERED_DOC_DIR = '../filtered_documents/'
MAX_EXAMPLE_LEN = 3
BLACK_WHITE_LIST_DIR = '../prefix_suffix_lists/'
FEATURE_LIST = [
    'contains_mex_char',
    'has_extras_in_middle',
    
    'next_word_verb',
    'all_proper_noun',
    
    'prefix_in_whitelist',
    'prefix_in_blacklist',
    'suffix_in_whitelist',
    'suffix_in_blacklist',
    
    'surrounded_by_paren',
    'has_left_comma',
    'has_right_comma',
    'has_left_period',
    'has_right_period',
    'first_last_word_capital',
    'surrounding_word_capital',
    'all_lowercase',

    'end_with_prime_s',
#     'tf',
#     'df',
#     'tf-idf'
]

# %%
prefix_black_set, prefix_white_set = set(), set()
suffix_black_set, suffix_white_set = set(), set()

# intialize all black list and white list
for black_prefix in open(BLACK_WHITE_LIST_DIR + 'prefix_black.txt', 'r').readlines():
    prefix_black_set.add(black_prefix.strip())
for white_prefix in open(BLACK_WHITE_LIST_DIR + 'prefix_white.txt', 'r').readlines():
    prefix_white_set.add(white_prefix.strip())
for black_suffix in open(BLACK_WHITE_LIST_DIR + 'suffix_black.txt', 'r').readlines():
    suffix_black_set.add(black_suffix.strip())
for white_suffix in open(BLACK_WHITE_LIST_DIR + 'suffix_white.txt', 'r').readlines():
    suffix_white_set.add(white_suffix.strip())
    
prefix_suffix_set = set()
prefix_suffix_set = prefix_black_set | prefix_white_set | suffix_black_set | suffix_white_set

# %%
# ========================================================================
#                                                                       ||
#                          Util Function                                ||
#                                                                       ||
# ========================================================================

def brackets_matching(example_padded, lbrace, rbrace):
    example_len = len(example_padded) - 4
    label = 0
    left_brace_max_index = -1
    for left_index in range(example_len-1, example_len+2):
        if lbrace in example_padded[left_index]:
            left_brace_max_index = left_index
    right_brace_min_index = len(example_padded)
    for right_index in range(4, 1, -1):
        if rbrace in example_padded[right_index]:
            right_brace_min_index = right_index
    if (left_brace_max_index > -1 and left_brace_max_index <= 2 and 
        right_brace_min_index < len(example_padded) and right_brace_min_index >= example_len+1):
        label = 1
    for left_index in range(example_len-1, example_len+1):
        if rbrace in example_padded[left_index] and left_index >= left_brace_max_index:
            label = 0
            break
    for right_index in range(4, 2, -1):
        if lbrace in example_padded[right_index] and right_index <= right_brace_min_index:
            label = 0
            break
    return label

def has_surrounded_symbol(example_padded, pos, symbol):
    example_len = len(example_padded) - 4
    if pos == 'left':
        if example_padded[1][-1] == symbol:
            return 1
        else:
            return 0
    else:
        if example_padded[example_len+1][-1] == symbol:
            return 1
        else:
            return 0

def remove_extras(s):
    if s in prefix_white_set or s in suffix_white_set:
        return s
    if s[-2:] == '\'s':
        s = s[:-2]
    s = re.sub('[^a-zA-Z]', '', s)
    return s

def gen_word_prop_dict(text):
    word_tag_dict = dict()
    words = nltk.word_tokenize(text)
    word_tags = nltk.pos_tag(words)
    for word, tag in word_tags:
        if word not in word_tag_dict:
            word_tag_dict[word] = tag
    return word_tag_dict

# %%
# ========================================================================
#                                                                       ||
#                        Feature and Label Generation                   ||
#                                                                       ||
# ========================================================================


# Generate feature matrix and label vector for a document and a particular example length

def gen_feature_label_example_len(text, example_len, word_tag_dict):
    
#     X_len = pd.DataFrame(columns=(['example'] + FEATURE_LIST))
    X_len = pd.DataFrame()
    y_len = pd.DataFrame(columns=['example', 'is_person_name'])
    parts = text.split(' ')
    index = 2
    while index+example_len+2 <= len(parts):
        example_padded = parts[index-2:index+example_len+2]
        example = ' '.join(example_padded[2:2+example_len])
        feature_dict = {'example': example}
        
        # ========================================================================
        # "example_padded" has the following form:                              ||
        # [pad_0, pad_1, word_1, ..., word_n,                 pad_-2, pad_-1]   ||
        #  0      1      2            len-3 (example_len+1)   len-2   len-1     ||
        # ========================================================================
        
        # generate "surrounded_by_paren" feature
        feature_dict['surrounded_by_paren'] = brackets_matching(example_padded, '(', ')')

        # generate "has_left_comma" feature
        feature_dict['has_left_comma'] = has_surrounded_symbol(example_padded, 'left', ',')
        
        # generate "has_right_comma" feature
        feature_dict['has_right_comma'] = has_surrounded_symbol(example_padded, 'right', ',')
        
        # generate "has_left_period" feature
        feature_dict['has_left_period'] = has_surrounded_symbol(example_padded, 'left', '.')
        
        # generate "has_right_period" feature
        feature_dict['has_right_period'] = has_surrounded_symbol(example_padded, 'right', '.')
        
        # generate "first_last_word_capital" feature
        first_capital = re.fullmatch('[^a-zA-Z]*[A-Z].*', example_padded[2])
        last_capital = re.fullmatch('[^a-zA-Z]*[A-Z].*', example_padded[1+example_len])
        feature_dict['first_last_word_capital'] = 1 if (first_capital and last_capital) else 0
        
        # generate "surrounding_word_capital" feature
        left_capital = re.fullmatch('[^a-zA-Z]*[A-Z].*', example_padded[1])
        right_capital = re.fullmatch('[^a-zA-Z]*[A-Z].*', example_padded[2+example_len])
        feature_dict['surrounding_word_capital'] = 1 if (left_capital or right_capital) else 0
        
        # generate "all_lowercase" feature
        feature_dict['all_lowercase'] = 1
        for i in range(2, 2+example_len):
            if re.fullmatch('[^A-Z]+', example_padded[i]) == None:
                feature_dict['all_lowercase'] = 0
                break
        
        # generate "prefix_in_whitelist" feature
        feature_dict['prefix_in_whitelist'] = 1 if remove_extras(example_padded[1]) in prefix_white_set else 0
        
        # generate "prefix_in_blacklist" feature
        feature_dict['prefix_in_blacklist'] = 1 if remove_extras(example_padded[1]) in prefix_black_set else 0
        
        # generate "suffix_in_whitelist" feature
        feature_dict['suffix_in_whitelist'] = 1 if remove_extras(example_padded[2 + example_len]) in suffix_white_set else 0
        
        # generate "suffix_in_blacklist" feature
        feature_dict['suffix_in_blacklist'] = 1 if remove_extras(example_padded[2 + example_len]) in suffix_black_set else 0
        
        # generate "end_with_prime_s" feature
        feature_dict['end_with_prime_s'] = 1 if (re.fullmatch('.*\'s', example_padded[1+example_len])) else 0
        
        # generate "next_word_verb" feautre, including be-verb
        next_word = remove_extras(example_padded[2 + example_len])
        if next_word in word_tag_dict and word_tag_dict[next_word].startswith('V'):
            feature_dict['next_word_verb'] = 1
        else:
            feature_dict['next_word_verb'] = 0

        # actually has_proper_noun
        feature_dict['all_noun'] = 1
        for word in example_padded[2:2 + example_len]:
            word = remove_extras(word)
            if word not in word_tag_dict or not word_tag_dict[word].startswith('NN'):
                feature_dict['all_noun'] = 0
                break
        
        feature_dict['contains_extras_in_middle'] = 0
        middle_chars = ' '.join(example_padded[2:2 + example_len])[2:-2]
        if re.search(r'[^a-zA-Z\s]', middle_chars):
            feature_dict['contains_extras_in_middle'] = 1
        
        # contains_amazing_char
        feature_dict['contains_amazing_char'] = 0 
        if re.search(r'[óéöä]', ' '.join(example_padded[2:2 + example_len])):
            feature_dict['contains_amazing_char'] = 1
        
        feature_dict['contains_prefix_suffix'] = 0
        for word in example_padded[2:2 + example_len]:
            if word in prefix_suffix_set:
                feature_dict['contains_prefix_suffix'] = 1
        
        # generate "tf" feature
        
        # generate "idf" feature
        
        # generate "tf-idf" feature

        
        X_len = X_len.append(feature_dict, ignore_index=True)

        # generate label
        label = brackets_matching(example_padded, '{', '}')
        y_len = y_len.append({'example': example, 'is_person_name': label}, ignore_index = True)

        index += 1

    return X_len, y_len

# Generate feature matrix and label vector for a document
def gen_feature_label_doc(doc_name):
#     X_doc = pd.DataFrame(columns=(['example'] + FEATURE_LIST))
    X_doc = pd.DataFrame()
    y_doc = pd.DataFrame(columns=['example', 'is_person_name'])
    doc = open(FILTERED_DOC_DIR+doc_name, 'r')
    text = ' '.join(doc.readlines()[2:]) # skip the title and empty line
    word_tag_dict = gen_word_prop_dict(text)
    
    text = '. . ' + text + ' . .' # pad with '. .' at both ends
    for example_len in range(1, MAX_EXAMPLE_LEN+1):
        X_len, y_len = gen_feature_label_example_len(text, example_len, word_tag_dict)
        X_doc = X_doc.append(X_len, ignore_index=True)
        y_doc = y_doc.append(y_len, ignore_index=True)
    return X_doc, y_doc

# %%
start = timeit.default_timer()

# documents are unordered
doc_list = os.listdir(FILTERED_DOC_DIR)

# documents are ordered
# doc_list = sorted(os.listdir(FILTERED_DOC_DIR), key = lambda x: int(x.split('.')[0]))

# X_train = pd.DataFrame(columns=(['example'] + FEATURE_LIST))
X_train = pd.DataFrame()
y_train = pd.DataFrame(columns=['example', 'is_person_name'])

# X_test = pd.DataFrame(columns=(['example'] + FEATURE_LIST))
X_test = pd.DataFrame(columns=())
y_test = pd.DataFrame(columns=['example', 'is_person_name'])

doc_list = doc_list[:10]
cutoff = int(0.8 * len(doc_list))
train_doc_list = doc_list[:cutoff]
test_doc_list = doc_list[cutoff:]

for doc_name in train_doc_list:
    X_doc, y_doc = gen_feature_label_doc(doc_name)
    X_train = X_train.append(X_doc, ignore_index=True)
    y_train = y_train.append(y_doc, ignore_index=True)

for doc_name in test_doc_list:
    X_doc, y_doc = gen_feature_label_doc(doc_name)
    X_test = X_test.append(X_doc, ignore_index=True)
    y_test = y_test.append(y_doc, ignore_index=True)
    
stop = timeit.default_timer()

print("Time used: ", stop - start)

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print(X.head(1000), y.head(1000))
# X.head(1000)
# y.head(1000)
# Out:
# Time used:  135.85795202499958

# %% [markdown]
# ## Next, we make our first attempt to train and evaluate a ML model with our dateset

# %%
X_train_no_example = X_train.drop(['example'], axis=1).astype('int')
X_test_no_example = X_test.drop(['example'], axis=1).astype('int')

y_train_no_example = y_train['is_person_name'].astype('int')
y_test_no_example = y_test['is_person_name'].astype('int')

clf = LogisticRegression(solver='lbfgs')
# clf = RandomForestClassifier()
clf.fit(X_train_no_example, y_train_no_example)
y_predict = clf.predict(X_test_no_example)

precision = precision_score(y_test_no_example, y_predict)
recall = recall_score(y_test_no_example, y_predict)

print("Precision: {:.2f}%, Recall: {:.2f}%\n".format(precision*100, recall*100))

X_test[np.not_equal(y_test_no_example, y_predict)].head(100)

# print(X_test[np.not_equal(y_test_no_example, y_predict)])
print(X_test[np.not_equal(y_test_no_example, y_predict)])

y_compare = y_test[np.not_equal(y_test_no_example, y_predict)]
y_compare['predicted_label'] = y_predict[np.not_equal(y_test_no_example, y_predict)]


print('=============================================')
print('False Positive: ')
print(y_compare[y_compare['predicted_label'] == 1])

print('=============================================')
print('False Negative: ')
print(y_compare[y_compare['predicted_label'] == 0])
# Out:
# Precision: 63.71%, Recall: 59.40%
#
#       all_lowercase  contains_extras_in_middle  contains_mex_char  \
# 358   0.0            0.0                        0.0
# 375   0.0            0.0                        0.0
# 395   0.0            0.0                        0.0
# 401   0.0            1.0                        0.0
# 404   0.0            0.0                        0.0
# 409   0.0            1.0                        0.0
# 418   0.0            0.0                        0.0
# 432   0.0            1.0                        0.0
# 436   0.0            0.0                        0.0
# 448   0.0            0.0                        0.0
# 451   0.0            0.0                        0.0
# 484   0.0            0.0                        0.0
# 790   1.0            0.0                        0.0
# 791   0.0            0.0                        0.0
# 802   0.0            0.0                        0.0
# 831   1.0            0.0                        0.0
# 867   0.0            0.0                        0.0
# 868   0.0            0.0                        0.0
# 909   0.0            0.0                        0.0
# 944   0.0            0.0                        0.0
# 1017  0.0            0.0                        0.0
# 1021  0.0            0.0                        0.0
# 1084  0.0            0.0                        0.0
# 1086  0.0            0.0                        0.0
# 1087  0.0            0.0                        0.0
# 1088  0.0            0.0                        0.0
# 1107  0.0            0.0                        0.0
# 1162  0.0            1.0                        0.0
# 1189  0.0            0.0                        0.0
# 1318  0.0            0.0                        0.0
# 1319  0.0            0.0                        0.0
# 1329  0.0            0.0                        0.0
# 1336  0.0            0.0                        0.0
# 1390  0.0            0.0                        0.0
# 1480  0.0            0.0                        0.0
# 1603  0.0            0.0                        0.0
# 1916  0.0            0.0                        0.0
# 1923  0.0            0.0                        0.0
# 1924  0.0            1.0                        0.0
# 1928  0.0            0.0                        0.0
# 1954  0.0            1.0                        0.0
# 1975  0.0            0.0                        0.0
# 2055  0.0            0.0                        0.0
# 2056  0.0            1.0                        1.0
# 2057  0.0            0.0                        0.0
# 2058  0.0            0.0                        0.0
# 2059  0.0            1.0                        0.0
# 2069  0.0            0.0                        0.0
# 2187  0.0            1.0                        1.0
# 2189  0.0            0.0                        0.0
# 2319  0.0            1.0                        1.0
# 2320  0.0            1.0                        0.0
# 2398  0.0            0.0                        0.0
# 2399  0.0            0.0                        0.0
# 2401  0.0            0.0                        0.0
# 2469  0.0            0.0                        0.0
# 2495  0.0            0.0                        0.0
# 2577  0.0            0.0                        0.0
# 2578  0.0            0.0                        0.0
# 2580  0.0            1.0                        0.0
# 2647  0.0            1.0                        0.0
# 2671  0.0            0.0                        0.0
# 2832  0.0            1.0                        0.0
# 2877  0.0            0.0                        0.0
# 3110  0.0            0.0                        0.0
# 3596  0.0            0.0                        0.0
# 3601  0.0            0.0                        0.0
# 3602  0.0            0.0                        0.0
# 3615  0.0            0.0                        0.0
# 3636  0.0            0.0                        0.0
# 3659  0.0            0.0                        0.0
# 3665  0.0            1.0                        0.0
# 3721  0.0            0.0                        0.0
# 3786  0.0            0.0                        0.0
# 3868  0.0            0.0                        0.0
# 3888  0.0            0.0                        0.0
# 3894  0.0            0.0                        0.0
# 3921  0.0            1.0                        0.0
# 3924  0.0            0.0                        0.0
# 3931  0.0            0.0                        0.0
# 4094  0.0            1.0                        0.0
# 4246  0.0            0.0                        0.0
# 4251  0.0            0.0                        0.0
# 4271  0.0            0.0                        0.0
# 4329  0.0            0.0                        0.0
# 4345  0.0            0.0                        0.0
# 4348  0.0            0.0                        0.0
# 4362  0.0            0.0                        0.0
# 4438  0.0            0.0                        0.0
# 4580  0.0            1.0                        0.0
# 4622  0.0            0.0                        0.0
# 4692  0.0            0.0                        0.0
# 4702  0.0            0.0                        0.0
# 4771  0.0            0.0                        0.0
# 4857  0.0            1.0                        0.0
# 5016  0.0            0.0                        0.0
# 5043  0.0            0.0                        0.0
# 5046  0.0            0.0                        0.0
# 5064  0.0            0.0                        0.0
#
#       contains_prefix_suffix  contains_proper_noun  end_with_prime_s  \
# 358   0.0                     0.0                   0.0
# 375   0.0                     0.0                   0.0
# 395   0.0                     0.0                   0.0
# 401   0.0                     1.0                   1.0
# 404   0.0                     0.0                   0.0
# 409   0.0                     1.0                   1.0
# 418   0.0                     1.0                   0.0
# 432   0.0                     1.0                   1.0
# 436   0.0                     0.0                   0.0
# 448   0.0                     1.0                   0.0
# 451   0.0                     0.0                   0.0
# 484   0.0                     1.0                   0.0
# 790   0.0                     0.0                   0.0
# 791   0.0                     1.0                   0.0
# 802   0.0                     1.0                   0.0
# 831   0.0                     0.0                   0.0
# 867   0.0                     1.0                   0.0
# 868   0.0                     1.0                   0.0
# 909   0.0                     1.0                   0.0
# 944   0.0                     1.0                   0.0
# 1017  0.0                     1.0                   0.0
# 1021  0.0                     1.0                   0.0
# 1084  0.0                     1.0                   0.0
# 1086  0.0                     1.0                   0.0
# 1087  0.0                     1.0                   0.0
# 1088  0.0                     1.0                   0.0
# 1107  0.0                     1.0                   0.0
# 1162  0.0                     1.0                   0.0
# 1189  0.0                     1.0                   0.0
# 1318  0.0                     1.0                   0.0
# 1319  0.0                     1.0                   0.0
# 1329  0.0                     1.0                   0.0
# 1336  0.0                     1.0                   0.0
# 1390  0.0                     1.0                   0.0
# 1480  0.0                     1.0                   0.0
# 1603  0.0                     1.0                   0.0
# 1916  0.0                     1.0                   0.0
# 1923  0.0                     1.0                   0.0
# 1924  0.0                     1.0                   1.0
# 1928  0.0                     1.0                   0.0
# 1954  0.0                     1.0                   1.0
# 1975  0.0                     1.0                   0.0
# 2055  0.0                     1.0                   0.0
# 2056  0.0                     0.0                   0.0
# 2057  0.0                     1.0                   0.0
# 2058  0.0                     1.0                   0.0
# 2059  0.0                     0.0                   0.0
# 2069  0.0                     1.0                   0.0
# 2187  0.0                     1.0                   0.0
# 2189  0.0                     1.0                   0.0
# 2319  0.0                     1.0                   0.0
# 2320  0.0                     1.0                   0.0
# 2398  0.0                     1.0                   0.0
# 2399  0.0                     1.0                   0.0
# 2401  0.0                     1.0                   0.0
# 2469  0.0                     0.0                   0.0
# 2495  0.0                     1.0                   0.0
# 2577  0.0                     1.0                   0.0
# 2578  0.0                     1.0                   0.0
# 2580  0.0                     0.0                   0.0
# 2647  0.0                     1.0                   1.0
# 2671  0.0                     1.0                   0.0
# 2832  0.0                     1.0                   1.0
# 2877  0.0                     1.0                   0.0
# 3110  0.0                     1.0                   0.0
# 3596  0.0                     1.0                   0.0
# 3601  0.0                     1.0                   0.0
# 3602  0.0                     0.0                   0.0
# 3615  0.0                     1.0                   0.0
# 3636  0.0                     1.0                   0.0
# 3659  0.0                     1.0                   0.0
# 3665  0.0                     1.0                   0.0
# 3721  0.0                     1.0                   0.0
# 3786  0.0                     0.0                   0.0
# 3868  0.0                     1.0                   0.0
# 3888  0.0                     1.0                   1.0
# 3894  0.0                     1.0                   0.0
# 3921  0.0                     1.0                   1.0
# 3924  0.0                     1.0                   0.0
# 3931  0.0                     1.0                   0.0
# 4094  0.0                     1.0                   0.0
# 4246  0.0                     1.0                   0.0
# 4251  0.0                     1.0                   0.0
# 4271  0.0                     1.0                   0.0
# 4329  0.0                     0.0                   0.0
# 4345  0.0                     1.0                   0.0
# 4348  0.0                     1.0                   0.0
# 4362  0.0                     1.0                   0.0
# 4438  0.0                     1.0                   0.0
# 4580  0.0                     1.0                   0.0
# 4622  0.0                     1.0                   0.0
# 4692  0.0                     1.0                   0.0
# 4702  0.0                     1.0                   0.0
# 4771  0.0                     1.0                   0.0
# 4857  0.0                     0.0                   0.0
# 5016  0.0                     1.0                   0.0
# 5043  0.0                     0.0                   0.0
# 5046  0.0                     1.0                   0.0
# 5064  0.0                     1.0                   0.0
#
#                             example  first_last_word_capital  has_left_comma  \
# 358   {Woody}.                       1.0                      0.0
# 375   {Woody}                        1.0                      0.0
# 395   {Woody}                        1.0                      0.0
# 401   {Andy}'s                       1.0                      0.0
# 404   {Woody}                        1.0                      0.0
# 409   {Andy}'s                       1.0                      0.0
# 418   {Buzz                          1.0                      0.0
# 432   {Andy}'s                       1.0                      0.0
# 436   {Woody},                       1.0                      0.0
# 448   {Buzz}.                        1.0                      0.0
# 451   {Woody}                        1.0                      0.0
# 484   Phillips}.                     1.0                      0.0
# 790   de                             0.0                      0.0
# 791   Winter}.                       1.0                      0.0
# 802   Manderley,                     1.0                      0.0
# 831   {de                            0.0                      0.0
# 867   {Maxim de                      0.0                      0.0
# 868   de Winter}.                    0.0                      0.0
# 909   {de Winter}                    0.0                      0.0
# 944   {Maxim de Winter}.             1.0                      0.0
# 1017  Atlanta                        1.0                      1.0
# 1021  Army                           1.0                      0.0
# 1084  War                            1.0                      0.0
# 1086  {Rhett                         1.0                      0.0
# 1087  Butler}.                       1.0                      0.0
# 1088  {Scarlett}                     1.0                      0.0
# 1107  {Melanie}.                     1.0                      0.0
# 1162  {Melanie}. Mammy               1.0                      1.0
# 1189  {Rhett Butler}.                1.0                      0.0
# 1318  {Jimmy                         1.0                      0.0
# 1319  Iovine}                        1.0                      0.0
# 1329  Brooklyn                       1.0                      0.0
# 1336  Compton                        1.0                      0.0
# 1390  "The Defiant Ones"             1.0                      0.0
# 1480  {Donald                        1.0                      0.0
# 1603  Madison Avenue                 1.0                      0.0
# 1916  South                          1.0                      0.0
# 1923  {Elizabeth                     1.0                      0.0
# 1924  Gaskell}'s                     1.0                      0.0
# 1928  {Margaret                      1.0                      0.0
# 1954  {Elizabeth Gaskell}'s          1.0                      0.0
# 1975  North and South                1.0                      0.0
# 2055  {Saga                          1.0                      0.0
# 2056  Norén},                        1.0                      0.0
# 2057  County                         1.0                      1.0
# 2058  Police,                        1.0                      0.0
# 2059  {Malmö},                       1.0                      1.0
# 2069  {Martin                        1.0                      0.0
# 2187  {Saga Norén},                  1.0                      0.0
# 2189  County Police,                 1.0                      1.0
# 2319  Norén}, County Police,         1.0                      0.0
# 2320  County Police, {Malmö},        1.0                      1.0
# 2398  Jeremy,                        1.0                      0.0
# 2399  Richard,                       1.0                      1.0
# 2401  James,                         1.0                      0.0
# 2469  {Mark}                         1.0                      0.0
# 2495  Mayhem                         1.0                      0.0
# 2577  {Malcom                        1.0                      0.0
# 2578  Crowe}                         1.0                      0.0
# 2580  Willis})is                     1.0                      0.0
# 2647  {Cole}'s                       1.0                      0.0
# 2671  {Malcom Crowe}                 1.0                      0.0
# 2832  ({Olivia Williams}). {Cole}'s  1.0                      0.0
# 2877  Earth                          1.0                      0.0
# 3110  Tokyo                          1.0                      0.0
# 3596  HOTEL                          1.0                      0.0
# 3601  {Gustave                       1.0                      0.0
# 3602  H.},                           1.0                      0.0
# 3615  {Zero                          1.0                      0.0
# 3636  Renaissance                    1.0                      0.0
# 3659  BUDAPEST HOTEL                 1.0                      0.0
# 3665  {Gustave H.},                  1.0                      0.0
# 3721  GRAND BUDAPEST HOTEL           1.0                      0.0
# 3786  K.                             1.0                      0.0
# 3868  India,                         1.0                      0.0
# 3888  India's                        1.0                      0.0
# 3894  {Gandhi}                       1.0                      0.0
# 3921  {Gandhi}'s                     1.0                      0.0
# 3924  Nevertheless,                  1.0                      0.0
# 3931  Britain                        1.0                      0.0
# 4094  {Mohandas K. Gandhi}           1.0                      1.0
# 4246  Rochelle,                      1.0                      0.0
# 4251  {Frank                         1.0                      0.0
# 4271  Manhattan                      1.0                      0.0
# 4329  And,                           1.0                      0.0
# 4345  FBI                            1.0                      0.0
# 4348  Hanratty}.                     1.0                      0.0
# 4362  New Rochelle,                  1.0                      0.0
# 4438  Pan Am                         1.0                      0.0
# 4580  {Carl Hanratty}. What          1.0                      1.0
# 4622  York,                          1.0                      0.0
# 4692  United States,                 1.0                      0.0
# 4702  New York,                      1.0                      0.0
# 4771  War United States,             1.0                      0.0
# 4857  {Nausicaä},                    1.0                      0.0
# 5016  {Andreiv                       1.0                      0.0
# 5043  Princes                        1.0                      0.0
# 5046  Tatar                          1.0                      0.0
# 5064  Century Russian                1.0                      0.0
#
#       has_left_period  has_right_comma  has_right_period  next_word_verb  \
# 358   0.0              0.0              1.0               0.0
# 375   1.0              0.0              0.0               1.0
# 395   0.0              0.0              0.0               1.0
# 401   0.0              0.0              0.0               0.0
# 404   1.0              0.0              0.0               1.0
# 409   0.0              0.0              0.0               0.0
# 418   0.0              0.0              0.0               0.0
# 432   0.0              0.0              0.0               0.0
# 436   1.0              1.0              0.0               0.0
# 448   0.0              0.0              1.0               0.0
# 451   0.0              0.0              0.0               0.0
# 484   0.0              0.0              1.0               0.0
# 790   0.0              0.0              0.0               0.0
# 791   0.0              0.0              1.0               0.0
# 802   0.0              1.0              0.0               0.0
# 831   1.0              0.0              0.0               0.0
# 867   0.0              0.0              0.0               0.0
# 868   0.0              0.0              1.0               0.0
# 909   1.0              0.0              0.0               1.0
# 944   0.0              0.0              1.0               0.0
# 1017  0.0              0.0              0.0               0.0
# 1021  0.0              0.0              0.0               1.0
# 1084  0.0              0.0              0.0               1.0
# 1086  1.0              0.0              0.0               0.0
# 1087  0.0              0.0              1.0               0.0
# 1088  1.0              0.0              0.0               1.0
# 1107  0.0              0.0              1.0               0.0
# 1162  0.0              0.0              0.0               1.0
# 1189  1.0              0.0              1.0               0.0
# 1318  0.0              0.0              0.0               0.0
# 1319  0.0              0.0              0.0               0.0
# 1329  0.0              0.0              0.0               0.0
# 1336  0.0              0.0              0.0               0.0
# 1390  1.0              0.0              0.0               1.0
# 1480  0.0              0.0              0.0               0.0
# 1603  0.0              0.0              0.0               0.0
# 1916  0.0              0.0              0.0               1.0
# 1923  0.0              0.0              0.0               0.0
# 1924  0.0              0.0              0.0               0.0
# 1928  0.0              0.0              0.0               0.0
# 1954  0.0              0.0              0.0               0.0
# 1975  1.0              0.0              0.0               1.0
# 2055  1.0              0.0              0.0               0.0
# 2056  0.0              1.0              0.0               0.0
# 2057  0.0              0.0              0.0               0.0
# 2058  0.0              1.0              0.0               0.0
# 2059  0.0              1.0              0.0               1.0
# 2069  0.0              0.0              0.0               0.0
# 2187  1.0              1.0              0.0               0.0
# 2189  0.0              1.0              0.0               0.0
# 2319  0.0              1.0              0.0               0.0
# 2320  0.0              1.0              0.0               1.0
# 2398  0.0              1.0              0.0               0.0
# 2399  0.0              1.0              0.0               0.0
# 2401  0.0              1.0              0.0               0.0
# 2469  1.0              0.0              0.0               0.0
# 2495  1.0              0.0              0.0               1.0
# 2577  1.0              0.0              0.0               0.0
# 2578  0.0              0.0              0.0               0.0
# 2580  0.0              0.0              0.0               0.0
# 2647  1.0              0.0              0.0               0.0
# 2671  1.0              0.0              0.0               0.0
# 2832  0.0              0.0              0.0               0.0
# 2877  0.0              0.0              0.0               0.0
# 3110  0.0              0.0              0.0               0.0
# 3596  0.0              0.0              0.0               1.0
# 3601  0.0              0.0              0.0               0.0
# 3602  0.0              1.0              0.0               0.0
# 3615  0.0              0.0              0.0               0.0
# 3636  0.0              0.0              0.0               0.0
# 3659  0.0              0.0              0.0               1.0
# 3665  0.0              1.0              0.0               0.0
# 3721  1.0              0.0              0.0               1.0
# 3786  0.0              0.0              1.0               0.0
# 3868  0.0              1.0              0.0               0.0
# 3888  0.0              0.0              0.0               0.0
# 3894  1.0              0.0              0.0               1.0
# 3921  0.0              0.0              0.0               0.0
# 3924  1.0              1.0              0.0               0.0
# 3931  0.0              0.0              0.0               1.0
# 4094  0.0              0.0              0.0               1.0
# 4246  0.0              1.0              0.0               0.0
# 4251  0.0              0.0              0.0               0.0
# 4271  0.0              0.0              0.0               0.0
# 4329  1.0              1.0              0.0               0.0
# 4345  0.0              0.0              0.0               0.0
# 4348  0.0              0.0              1.0               0.0
# 4362  1.0              1.0              0.0               0.0
# 4438  0.0              0.0              0.0               0.0
# 4580  0.0              0.0              0.0               1.0
# 4622  0.0              1.0              0.0               1.0
# 4692  0.0              1.0              0.0               0.0
# 4702  0.0              1.0              0.0               1.0
# 4771  0.0              1.0              0.0               0.0
# 4857  0.0              1.0              0.0               0.0
# 5016  1.0              0.0              0.0               0.0
# 5043  0.0              0.0              0.0               0.0
# 5046  0.0              0.0              0.0               0.0
# 5064  0.0              0.0              0.0               0.0
#
#       prefix_in_blacklist  prefix_in_whitelist  suffix_in_blacklist  \
# 358   0.0                  1.0                  0.0
# 375   0.0                  0.0                  0.0
# 395   0.0                  0.0                  0.0
# 401   0.0                  0.0                  0.0
# 404   0.0                  0.0                  0.0
# 409   0.0                  0.0                  0.0
# 418   0.0                  0.0                  0.0
# 432   0.0                  0.0                  0.0
# 436   0.0                  0.0                  0.0
# 448   0.0                  0.0                  0.0
# 451   0.0                  0.0                  0.0
# 484   0.0                  0.0                  0.0
# 790   0.0                  0.0                  0.0
# 791   0.0                  0.0                  0.0
# 802   0.0                  0.0                  0.0
# 831   0.0                  1.0                  0.0
# 867   0.0                  0.0                  0.0
# 868   0.0                  0.0                  0.0
# 909   0.0                  1.0                  0.0
# 944   0.0                  0.0                  0.0
# 1017  0.0                  0.0                  0.0
# 1021  0.0                  0.0                  0.0
# 1084  0.0                  0.0                  0.0
# 1086  0.0                  0.0                  0.0
# 1087  0.0                  0.0                  0.0
# 1088  0.0                  0.0                  0.0
# 1107  0.0                  0.0                  0.0
# 1162  0.0                  1.0                  0.0
# 1189  0.0                  0.0                  0.0
# 1318  0.0                  0.0                  0.0
# 1319  0.0                  0.0                  0.0
# 1329  0.0                  0.0                  0.0
# 1336  0.0                  0.0                  0.0
# 1390  0.0                  0.0                  0.0
# 1480  0.0                  0.0                  0.0
# 1603  0.0                  0.0                  0.0
# 1916  0.0                  0.0                  0.0
# 1923  0.0                  0.0                  0.0
# 1924  0.0                  0.0                  0.0
# 1928  0.0                  0.0                  0.0
# 1954  0.0                  0.0                  0.0
# 1975  0.0                  0.0                  0.0
# 2055  0.0                  0.0                  0.0
# 2056  0.0                  0.0                  0.0
# 2057  0.0                  0.0                  0.0
# 2058  0.0                  0.0                  0.0
# 2059  0.0                  0.0                  0.0
# 2069  0.0                  0.0                  0.0
# 2187  0.0                  0.0                  0.0
# 2189  0.0                  0.0                  0.0
# 2319  0.0                  0.0                  0.0
# 2320  0.0                  0.0                  0.0
# 2398  0.0                  0.0                  0.0
# 2399  0.0                  0.0                  0.0
# 2401  0.0                  0.0                  0.0
# 2469  0.0                  0.0                  0.0
# 2495  0.0                  0.0                  0.0
# 2577  0.0                  0.0                  0.0
# 2578  0.0                  0.0                  0.0
# 2580  0.0                  0.0                  0.0
# 2647  0.0                  0.0                  0.0
# 2671  0.0                  0.0                  0.0
# 2832  0.0                  1.0                  0.0
# 2877  0.0                  0.0                  0.0
# 3110  0.0                  0.0                  0.0
# 3596  0.0                  0.0                  0.0
# 3601  0.0                  0.0                  0.0
# 3602  0.0                  0.0                  0.0
# 3615  0.0                  0.0                  0.0
# 3636  0.0                  0.0                  0.0
# 3659  0.0                  0.0                  0.0
# 3665  0.0                  0.0                  0.0
# 3721  0.0                  0.0                  0.0
# 3786  0.0                  0.0                  0.0
# 3868  0.0                  0.0                  0.0
# 3888  0.0                  0.0                  0.0
# 3894  0.0                  0.0                  0.0
# 3921  0.0                  0.0                  0.0
# 3924  0.0                  0.0                  0.0
# 3931  0.0                  0.0                  0.0
# 4094  0.0                  0.0                  0.0
# 4246  0.0                  0.0                  0.0
# 4251  0.0                  0.0                  0.0
# 4271  0.0                  0.0                  0.0
# 4329  0.0                  1.0                  0.0
# 4345  0.0                  0.0                  0.0
# 4348  0.0                  0.0                  0.0
# 4362  0.0                  0.0                  0.0
# 4438  0.0                  0.0                  0.0
# 4580  0.0                  1.0                  0.0
# 4622  0.0                  0.0                  0.0
# 4692  0.0                  0.0                  0.0
# 4702  0.0                  0.0                  0.0
# 4771  0.0                  0.0                  0.0
# 4857  0.0                  0.0                  0.0
# 5016  0.0                  0.0                  0.0
# 5043  0.0                  1.0                  0.0
# 5046  0.0                  0.0                  0.0
# 5064  0.0                  0.0                  0.0
#
#       suffix_in_whitelist  surrounded_by_paren  surrounding_word_capital
# 358   0.0                  0.0                  1.0
# 375   0.0                  0.0                  0.0
# 395   0.0                  0.0                  0.0
# 401   0.0                  0.0                  0.0
# 404   0.0                  0.0                  0.0
# 409   0.0                  0.0                  0.0
# 418   0.0                  0.0                  1.0
# 432   0.0                  0.0                  0.0
# 436   1.0                  0.0                  0.0
# 448   0.0                  0.0                  1.0
# 451   0.0                  0.0                  0.0
# 484   0.0                  0.0                  1.0
# 790   0.0                  0.0                  1.0
# 791   0.0                  0.0                  1.0
# 802   0.0                  0.0                  0.0
# 831   0.0                  0.0                  1.0
# 867   0.0                  0.0                  1.0
# 868   0.0                  0.0                  1.0
# 909   0.0                  0.0                  1.0
# 944   0.0                  0.0                  1.0
# 1017  0.0                  0.0                  0.0
# 1021  0.0                  0.0                  1.0
# 1084  0.0                  0.0                  1.0
# 1086  0.0                  0.0                  1.0
# 1087  0.0                  0.0                  1.0
# 1088  0.0                  0.0                  1.0
# 1107  0.0                  0.0                  0.0
# 1162  0.0                  0.0                  0.0
# 1189  0.0                  0.0                  1.0
# 1318  0.0                  0.0                  1.0
# 1319  0.0                  0.0                  1.0
# 1329  0.0                  0.0                  0.0
# 1336  0.0                  0.0                  0.0
# 1390  0.0                  0.0                  0.0
# 1480  0.0                  0.0                  1.0
# 1603  0.0                  0.0                  0.0
# 1916  1.0                  0.0                  0.0
# 1923  0.0                  0.0                  1.0
# 1924  0.0                  0.0                  1.0
# 1928  0.0                  0.0                  1.0
# 1954  0.0                  0.0                  0.0
# 1975  1.0                  0.0                  0.0
# 2055  0.0                  0.0                  1.0
# 2056  0.0                  0.0                  1.0
# 2057  0.0                  0.0                  1.0
# 2058  0.0                  0.0                  1.0
# 2059  1.0                  0.0                  1.0
# 2069  0.0                  0.0                  1.0
# 2187  0.0                  0.0                  1.0
# 2189  0.0                  0.0                  1.0
# 2319  0.0                  0.0                  1.0
# 2320  1.0                  0.0                  1.0
# 2398  0.0                  0.0                  1.0
# 2399  0.0                  0.0                  1.0
# 2401  0.0                  0.0                  0.0
# 2469  0.0                  0.0                  0.0
# 2495  0.0                  0.0                  0.0
# 2577  0.0                  0.0                  1.0
# 2578  0.0                  0.0                  1.0
# 2580  0.0                  1.0                  1.0
# 2647  0.0                  0.0                  1.0
# 2671  0.0                  0.0                  1.0
# 2832  0.0                  0.0                  0.0
# 2877  0.0                  0.0                  0.0
# 3110  0.0                  0.0                  0.0
# 3596  0.0                  0.0                  1.0
# 3601  0.0                  0.0                  1.0
# 3602  0.0                  0.0                  1.0
# 3615  0.0                  0.0                  1.0
# 3636  0.0                  0.0                  0.0
# 3659  0.0                  0.0                  1.0
# 3665  0.0                  0.0                  0.0
# 3721  0.0                  0.0                  0.0
# 3786  0.0                  0.0                  1.0
# 3868  0.0                  0.0                  0.0
# 3888  0.0                  0.0                  0.0
# 3894  0.0                  0.0                  1.0
# 3921  0.0                  0.0                  0.0
# 3924  0.0                  0.0                  0.0
# 3931  0.0                  0.0                  0.0
# 4094  1.0                  0.0                  0.0
# 4246  0.0                  0.0                  1.0
# 4251  0.0                  0.0                  1.0
# 4271  0.0                  0.0                  0.0
# 4329  0.0                  0.0                  0.0
# 4345  0.0                  0.0                  0.0
# 4348  0.0                  0.0                  1.0
# 4362  0.0                  0.0                  0.0
# 4438  0.0                  0.0                  0.0
# 4580  0.0                  0.0                  0.0
# 4622  1.0                  0.0                  1.0
# 4692  0.0                  0.0                  1.0
# 4702  1.0                  0.0                  0.0
# 4771  0.0                  0.0                  1.0
# 4857  0.0                  0.0                  1.0
# 5016  0.0                  0.0                  1.0
# 5043  0.0                  0.0                  0.0
# 5046  0.0                  0.0                  0.0
# 5064  0.0                  0.0                  0.0
# =============================================
# False Positive:
#                             example is_person_name  predicted_label
# 802   Manderley,                     0              1
# 1017  Atlanta                        0              1
# 1021  Army                           0              1
# 1084  War                            0              1
# 1162  {Melanie}. Mammy               0              1
# 1329  Brooklyn                       0              1
# 1336  Compton                        0              1
# 1390  "The Defiant Ones"             0              1
# 1603  Madison Avenue                 0              1
# 1916  South                          0              1
# 1975  North and South                0              1
# 2057  County                         0              1
# 2058  Police,                        0              1
# 2189  County Police,                 0              1
# 2319  Norén}, County Police,         0              1
# 2320  County Police, {Malmö},        0              1
# 2398  Jeremy,                        0              1
# 2399  Richard,                       0              1
# 2401  James,                         0              1
# 2495  Mayhem                         0              1
# 2832  ({Olivia Williams}). {Cole}'s  0              1
# 2877  Earth                          0              1
# 3110  Tokyo                          0              1
# 3596  HOTEL                          0              1
# 3636  Renaissance                    0              1
# 3659  BUDAPEST HOTEL                 0              1
# 3721  GRAND BUDAPEST HOTEL           0              1
# 3868  India,                         0              1
# 3888  India's                        0              1
# 3924  Nevertheless,                  0              1
# 3931  Britain                        0              1
# 4246  Rochelle,                      0              1
# 4271  Manhattan                      0              1
# 4329  And,                           0              1
# 4345  FBI                            0              1
# 4362  New Rochelle,                  0              1
# 4438  Pan Am                         0              1
# 4580  {Carl Hanratty}. What          0              1
# 4622  York,                          0              1
# 4692  United States,                 0              1
# 4702  New York,                      0              1
# 4771  War United States,             0              1
# 5043  Princes                        0              1
# 5046  Tatar                          0              1
# 5064  Century Russian                0              1
# =============================================
# False Negative:
#                     example is_person_name  predicted_label
# 358   {Woody}.               1              0
# 375   {Woody}                1              0
# 395   {Woody}                1              0
# 401   {Andy}'s               1              0
# 404   {Woody}                1              0
# 409   {Andy}'s               1              0
# 418   {Buzz                  1              0
# 432   {Andy}'s               1              0
# 436   {Woody},               1              0
# 448   {Buzz}.                1              0
# 451   {Woody}                1              0
# 484   Phillips}.             1              0
# 790   de                     1              0
# 791   Winter}.               1              0
# 831   {de                    1              0
# 867   {Maxim de              1              0
# 868   de Winter}.            1              0
# 909   {de Winter}            1              0
# 944   {Maxim de Winter}.     1              0
# 1086  {Rhett                 1              0
# 1087  Butler}.               1              0
# 1088  {Scarlett}             1              0
# 1107  {Melanie}.             1              0
# 1189  {Rhett Butler}.        1              0
# 1318  {Jimmy                 1              0
# 1319  Iovine}                1              0
# 1480  {Donald                1              0
# 1923  {Elizabeth             1              0
# 1924  Gaskell}'s             1              0
# 1928  {Margaret              1              0
# 1954  {Elizabeth Gaskell}'s  1              0
# 2055  {Saga                  1              0
# 2056  Norén},                1              0
# 2059  {Malmö},               1              0
# 2069  {Martin                1              0
# 2187  {Saga Norén},          1              0
# 2469  {Mark}                 1              0
# 2577  {Malcom                1              0
# 2578  Crowe}                 1              0
# 2580  Willis})is             1              0
# 2647  {Cole}'s               1              0
# 2671  {Malcom Crowe}         1              0
# 3601  {Gustave               1              0
# 3602  H.},                   1              0
# 3615  {Zero                  1              0
# 3665  {Gustave H.},          1              0
# 3786  K.                     1              0
# 3894  {Gandhi}               1              0
# 3921  {Gandhi}'s             1              0
# 4094  {Mohandas K. Gandhi}   1              0
# 4251  {Frank                 1              0
# 4348  Hanratty}.             1              0
# 4857  {Nausicaä},            1              0
# 5016  {Andreiv               1              0
# /Users/gtbai/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
